# %%
# Data Frame

# %%
import pandas as pd
df = pd.read_csv('newCarReg2016.csv')

# %%
df
# Out:
#      month          brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  \
# 0        1     ALFA ROMEO       0       0       0       0         1     0
# 1        1           AUDI       0       2       0      14         0     0
# 2        1        BENTLEY       0       0       0       0         2     0
# 3        1            BMW       1      45       0     586        64     0
# 4        1       CADILLAC       0       0       0       0         1     0
# 5        1          CHERY       0       0       0       1         0     0
# 6        1      CHEVROLET       0     103      59      80       501     0
# 7        1        FERRARI       0       0       0       0         2     0
# 8        1           FIAT       0       3       0       0         1     0
# 9        1           FORD      73     525       0      40      2503     0
# 10       1          HONDA     333    7500    3504    1467       232     0
# 11       1        HYUNDAI       0       2      29       2        57     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 9 columns):
# month       430 non-null int64
# brand       430 non-null object
# 1300cc      430 non-null int64
# 1600cc      430 non-null int64
# 1800cc      430 non-null int64
# 2000cc      430 non-null int64
# gt2000cc    430 non-null int64
# elec        430 non-null int64
# total       430 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 30.3+ KB

# %%
df.shape
# Out:
# (430, 9)

# %%
df[400:411:]
# Out:
#      month        brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  total
# 400     12    CHEVROLET       0       4      24      18       283     0    329
# 401     12      FERRARI       0       0       0       0         3     0      3
# 402     12         FORD       3     145       0       3      1411     0   1562
# 403     12        HONDA     118    2595    1340     348        85     0   4486
# 404     12      HYUNDAI       0       3      14       0        16     0     33
# 405     12        ISUZU       0       0       0    2056       522     0   2578
# 406     12       JAGUAR       0       0       0       1         1     0      2
# 407     12          KIA       1       0       0       1         2     0      4
# 408     12  LAMBORGHINI       0       0       0       0         3     0      3
# 409     12   LAND ROVER       0       0       0       0         2     0      2
# 410     12        LEXUS       0       0       0      13        19     0     32

# %%
df[:4]
# Out:
#    month       brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  total
# 0      1  ALFA ROMEO       0       0       0       0         1     0      1
# 1      1        AUDI       0       2       0      14         0     0     16
# 2      1     BENTLEY       0       0       0       0         2     0      2
# 3      1         BMW       1      45       0     586        64     0    696

# %%
import matplotlib.pyplot as plt

# %%
df1 = pd.concat([df[1:10:2],df[400:411]])

# %%
plt.plot(df['month'],df['total'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 1 to 410
# Data columns (total 9 columns):
# month       16 non-null int64
# brand       16 non-null object
# 1300cc      16 non-null int64
# 1600cc      16 non-null int64
# 1800cc      16 non-null int64
# 2000cc      16 non-null int64
# gt2000cc    16 non-null int64
# elec        16 non-null int64
# total       16 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 1.2+ KB

# %%
df1['smallEngine'] = df1['1300cc'] + df1['1600cc']
df1['mediumEngine'] = df1['1800cc'] + df1['2000cc']
df1['largeEngine'] = df1['gt2000cc']

# %%
df1
# Out:
#      month        brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  \
# 1        1         AUDI       0       2       0      14         0     0
# 3        1          BMW       1      45       0     586        64     0
# 5        1        CHERY       0       0       0       1         0     0
# 7        1      FERRARI       0       0       0       0         2     0
# 9        1         FORD      73     525       0      40      2503     0
# 400     12    CHEVROLET       0       4      24      18       283     0
# 401     12      FERRARI       0       0       0       0         3     0
# 402     12         FORD       3     145       0       3      1411     0
# 403     12        HONDA     118    2595    1340     348        85     0
# 404     12      HYUNDAI       0       3      14       0        16     0
# 405     12        ISUZU       0       0       0    2056       522     0
# 406     12       JAGUAR       0       0       0       1         1     0
# ...

# %%
df1['specialCode'] = df1['brand'].str[0:3] + '-' + df1['total'].astype(str)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 1 to 410
# Data columns (total 13 columns):
# month           16 non-null int64
# brand           16 non-null object
# 1300cc          16 non-null int64
# 1600cc          16 non-null int64
# 1800cc          16 non-null int64
# 2000cc          16 non-null int64
# gt2000cc        16 non-null int64
# elec            16 non-null int64
# total           16 non-null int64
# smallEngine     16 non-null int64
# mediumEngine    16 non-null int64
# largeEngine     16 non-null int64
# specialCode     16 non-null object
# dtypes: int64(11), object(2)
# memory usage: 2.4+ KB

# %%
import numpy as np

# %%
df1['status'] = np.where(df1['total'] > 10,'good','bad')

# %%
df1
# Out:
#      month        brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  \
# 1        1         AUDI       0       2       0      14         0     0
# 3        1          BMW       1      45       0     586        64     0
# 5        1        CHERY       0       0       0       1         0     0
# 7        1      FERRARI       0       0       0       0         2     0
# 9        1         FORD      73     525       0      40      2503     0
# 400     12    CHEVROLET       0       4      24      18       283     0
# 401     12      FERRARI       0       0       0       0         3     0
# 402     12         FORD       3     145       0       3      1411     0
# 403     12        HONDA     118    2595    1340     348        85     0
# 404     12      HYUNDAI       0       3      14       0        16     0
# 405     12        ISUZU       0       0       0    2056       522     0
# 406     12       JAGUAR       0       0       0       1         1     0
# ...

# %%
df1['evSec'] = np.where((df1['1300cc'] > 0) & (df1['1600cc'] > 0) & (df1['1800cc'] > 0) & (df1['2000cc'] > 0) & (df1['gt2000cc'] > 0),'yes','no')

# %%
df1
# Out:
#      month        brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  \
# 1        1         AUDI       0       2       0      14         0     0
# 3        1          BMW       1      45       0     586        64     0
# 5        1        CHERY       0       0       0       1         0     0
# 7        1      FERRARI       0       0       0       0         2     0
# 9        1         FORD      73     525       0      40      2503     0
# 400     12    CHEVROLET       0       4      24      18       283     0
# 401     12      FERRARI       0       0       0       0         3     0
# 402     12         FORD       3     145       0       3      1411     0
# 403     12        HONDA     118    2595    1340     348        85     0
# 404     12      HYUNDAI       0       3      14       0        16     0
# 405     12        ISUZU       0       0       0    2056       522     0
# 406     12       JAGUAR       0       0       0       1         1     0
# ...

# %%
df1['evSec1'] = np.where((df1['1300cc'] > 0) & (df1['1600cc'] > 0) & (df1['1800cc'] > 0) & (df1['2000cc'] > 0) & (df1['gt2000cc'] > 0),'yes','no')

# %%
df1
# Out:
#      month        brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  \
# 1        1         AUDI       0       2       0      14         0     0
# 3        1          BMW       1      45       0     586        64     0
# 5        1        CHERY       0       0       0       1         0     0
# 7        1      FERRARI       0       0       0       0         2     0
# 9        1         FORD      73     525       0      40      2503     0
# 400     12    CHEVROLET       0       4      24      18       283     0
# 401     12      FERRARI       0       0       0       0         3     0
# 402     12         FORD       3     145       0       3      1411     0
# 403     12        HONDA     118    2595    1340     348        85     0
# 404     12      HYUNDAI       0       3      14       0        16     0
# 405     12        ISUZU       0       0       0    2056       522     0
# 406     12       JAGUAR       0       0       0       1         1     0
# ...

# %%
del df1['evSec1']

# %%
df1
# Out:
#      month        brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  \
# 1        1         AUDI       0       2       0      14         0     0
# 3        1          BMW       1      45       0     586        64     0
# 5        1        CHERY       0       0       0       1         0     0
# 7        1      FERRARI       0       0       0       0         2     0
# 9        1         FORD      73     525       0      40      2503     0
# 400     12    CHEVROLET       0       4      24      18       283     0
# 401     12      FERRARI       0       0       0       0         3     0
# 402     12         FORD       3     145       0       3      1411     0
# 403     12        HONDA     118    2595    1340     348        85     0
# 404     12      HYUNDAI       0       3      14       0        16     0
# 405     12        ISUZU       0       0       0    2056       522     0
# 406     12       JAGUAR       0       0       0       1         1     0
# ...

# %%
df1.max(numeric_only=True)
# Out:
# month             12
# 1300cc           118
# 1600cc          2595
# 1800cc          1340
# 2000cc          2056
# gt2000cc        2503
# elec               0
# total           4486
# smallEngine     2713
# mediumEngine    2056
# largeEngine     2503
# dtype: int64

# %%
df1.describe()
# Out:
#            month      1300cc       1600cc       1800cc       2000cc  \
# count  16.000000   16.000000    16.000000    16.000000    16.000000
# mean    8.562500   12.250000   207.437500    86.125000   192.562500
# std     5.265849   33.529092   650.345751   334.434024   522.854469
# min     1.000000    0.000000     0.000000     0.000000     0.000000
# 25%     1.000000    0.000000     0.000000     0.000000     0.000000
# 50%    12.000000    0.000000     0.000000     0.000000     2.000000
# 75%    12.000000    1.000000    14.250000     0.000000    23.500000
# max    12.000000  118.000000  2595.000000  1340.000000  2056.000000
#
#          gt2000cc  elec        total  smallEngine  mediumEngine  largeEngine
# count    16.00000  16.0    16.000000    16.000000     16.000000     16.00000
# mean    307.25000   0.0   805.625000   219.687500    278.687500    307.25000
# std     688.47808   0.0  1397.296717   681.655897    641.931743    688.47808
# ...

# %%
df1.describe().T
# Out:
#               count      mean          std  min   25%   50%     75%     max
# month          16.0    8.5625     5.265849  1.0  1.00  12.0   12.00    12.0
# 1300cc         16.0   12.2500    33.529092  0.0  0.00   0.0    1.00   118.0
# 1600cc         16.0  207.4375   650.345751  0.0  0.00   0.0   14.25  2595.0
# 1800cc         16.0   86.1250   334.434024  0.0  0.00   0.0    0.00  1340.0
# 2000cc         16.0  192.5625   522.854469  0.0  0.00   2.0   23.50  2056.0
# gt2000cc       16.0  307.2500   688.478080  0.0  2.00   9.5  134.50  2503.0
# elec           16.0    0.0000     0.000000  0.0  0.00   0.0    0.00     0.0
# total          16.0  805.6250  1397.296717  1.0  2.75  24.0  912.50  4486.0
# smallEngine    16.0  219.6875   681.655897  0.0  0.00   0.5   14.50  2713.0
# mediumEngine   16.0  278.6875   641.931743  0.0  0.75   8.0   40.50  2056.0
# largeEngine    16.0  307.2500   688.478080  0.0  2.00   9.5  134.50  2503.0
