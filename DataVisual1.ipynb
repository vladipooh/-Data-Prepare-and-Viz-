# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
#https://docs.google.com/spreadsheets/d/1VE9jIHirEueZKm1QKUTbKZQAb7gyQW5BQJFoIBGUVJc/edit#gid=169651149
url = 'https://docs.google.com/spreadsheets/d/1VE9jIHirEueZKm1QKUTbKZQAb7gyQW5BQJFoIBGUVJc/export?gid=169651149&format=csv'
dfcar = pd.read_csv(url)

# %%
dfcar
# Out:
#     manufacturer               model  year        type  engine  cyl  \
# 0           audi                  a4  1999     compact     1.8    4
# 1           audi                  a4  1999     compact     1.8    4
# 2           audi                  a4  2008     compact     2.0    4
# 3           audi                  a4  2008     compact     2.0    4
# 4           audi                  a4  1999     compact     2.8    6
# 5           audi                  a4  1999     compact     2.8    6
# 6           audi                  a4  2008     compact     3.1    6
# 7           audi          a4 quattro  1999     compact     1.8    4
# 8           audi          a4 quattro  1999     compact     1.8    4
# 9           audi          a4 quattro  2008     compact     2.0    4
# 10          audi          a4 quattro  2008     compact     2.0    4
# 11          audi          a4 quattro  1999     compact     2.8    6
# 12          audi          a4 quattro  1999     compact     2.8    6
# ...

# %%
dfcar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 10 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# year            234 non-null int64
# type            234 non-null object
# engine          234 non-null float64
# cyl             234 non-null int64
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 18.4+ KB

# %%
# histogram
dfcar.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fecf11085c0>,
# ...
#       dtype=object)

# %%
dfcar['engine'].hist(bins=20,grid=False);

# %%
dfcar[['cty','hwy']].hist(bins=20,grid=False);

# %%
# %config InlineBackend.figure_format= 'retina'
