# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('import_data/ibmSalesProductsExample.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88475 entries, 0 to 88474
# Data columns (total 11 columns):
# Retailer country     88475 non-null object
# Order method type    88475 non-null object
# Retailer type        88475 non-null object
# Product line         88475 non-null object
# Product type         88475 non-null object
# Product              88475 non-null object
# Year                 88475 non-null int64
# Quarter              88475 non-null object
# Revenue              88475 non-null float64
# Quantity             88475 non-null int64
# Gross margin         87894 non-null float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 7.4+ MB

# %%
df['q_new'] =  df['Quarter'].str[0:2]

# %%
df['Quarter'] =  df['Quarter'].str[0:2]

# %%
df.drop(['q_new'],axis=1)
# Out:
#       Retailer country Order method type  Retailer type  \
# 0        United States               Fax  Outdoors Shop
# 1        United States               Fax  Outdoors Shop
# 2        United States               Fax  Outdoors Shop
# 3        United States               Fax  Outdoors Shop
# 4        United States               Fax  Outdoors Shop
# 5        United States               Fax  Outdoors Shop
# 6        United States               Fax  Outdoors Shop
# 7        United States               Fax  Outdoors Shop
# 8        United States               Fax  Outdoors Shop
# 9        United States               Fax  Outdoors Shop
# 10       United States               Fax  Outdoors Shop
# 11       United States               Fax  Outdoors Shop
# 12       United States               Fax  Outdoors Shop
# 13       United States               Fax  Outdoors Shop
# 14       United States               Fax  Outdoors Shop
# 15       United States               Fax  Outdoors Shop
# ...

# %%
df.to_csv('export_data/salesNew.csv',index_label='id')

# %%
df[0:84000:1000]
# Out:
#       Retailer country Order method type     Retailer type  \
# 0        United States               Fax     Outdoors Shop
# 1000            Canada            E-mail     Outdoors Shop
# 2000            Brazil               Web     Outdoors Shop
# 3000         Singapore               Web     Outdoors Shop
# 4000         Australia       Sales visit   Warehouse Store
# 5000           Finland               Web     Outdoors Shop
# 6000           Germany               Web     Outdoors Shop
# 7000    United Kingdom               Web  Department Store
# 8000             Italy            E-mail      Sports Store
# 9000     United States               Web         Golf Shop
# 10000           Canada               Web      Sports Store
# 11000            Japan               Web  Department Store
# 12000            China         Telephone     Outdoors Shop
# 13000      Netherlands               Web     Outdoors Shop
# 14000           France         Telephone         Golf Shop
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88475 entries, 0 to 88474
# Data columns (total 11 columns):
# Retailer country     88475 non-null object
# Order method type    88475 non-null object
# Retailer type        88475 non-null object
# Product line         88475 non-null object
# Product type         88475 non-null object
# Product              88475 non-null object
# Year                 88475 non-null int64
# Quarter              88475 non-null object
# Revenue              88475 non-null float64
# Quantity             88475 non-null int64
# Gross margin         87894 non-null float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 7.4+ MB

# %%
df['Quarter'] =  df['Quarter'].str[0:2]

# %%
df['Gross margin'] = df['Gross margin']*100

# %%
df
# Out:
#       Retailer country Order method type  Retailer type  \
# 0        United States               Fax  Outdoors Shop
# 1        United States               Fax  Outdoors Shop
# 2        United States               Fax  Outdoors Shop
# 3        United States               Fax  Outdoors Shop
# 4        United States               Fax  Outdoors Shop
# 5        United States               Fax  Outdoors Shop
# 6        United States               Fax  Outdoors Shop
# 7        United States               Fax  Outdoors Shop
# 8        United States               Fax  Outdoors Shop
# 9        United States               Fax  Outdoors Shop
# 10       United States               Fax  Outdoors Shop
# 11       United States               Fax  Outdoors Shop
# 12       United States               Fax  Outdoors Shop
# 13       United States               Fax  Outdoors Shop
# 14       United States               Fax  Outdoors Shop
# 15       United States               Fax  Outdoors Shop
# ...

# %%
df['Status'] = np.where(df['Gross margin'] > 50,'Gold',(np.where(df['Gross margin'] < 30,'Bronze','Silver')))

# %%
df
# Out:
#       Retailer country Order method type  Retailer type  \
# 0        United States               Fax  Outdoors Shop
# 1        United States               Fax  Outdoors Shop
# 2        United States               Fax  Outdoors Shop
# 3        United States               Fax  Outdoors Shop
# 4        United States               Fax  Outdoors Shop
# 5        United States               Fax  Outdoors Shop
# 6        United States               Fax  Outdoors Shop
# 7        United States               Fax  Outdoors Shop
# 8        United States               Fax  Outdoors Shop
# 9        United States               Fax  Outdoors Shop
# 10       United States               Fax  Outdoors Shop
# 11       United States               Fax  Outdoors Shop
# 12       United States               Fax  Outdoors Shop
# 13       United States               Fax  Outdoors Shop
# 14       United States               Fax  Outdoors Shop
# 15       United States               Fax  Outdoors Shop
# ...

# %%
df_pt = df[0:84000:1000]

# %%
df_pt
# Out:
#       Retailer country Order method type     Retailer type  \
# 0        United States               Fax     Outdoors Shop
# 1000            Canada            E-mail     Outdoors Shop
# 2000            Brazil               Web     Outdoors Shop
# 3000         Singapore               Web     Outdoors Shop
# 4000         Australia       Sales visit   Warehouse Store
# 5000           Finland               Web     Outdoors Shop
# 6000           Germany               Web     Outdoors Shop
# 7000    United Kingdom               Web  Department Store
# 8000             Italy            E-mail      Sports Store
# 9000     United States               Web         Golf Shop
# 10000           Canada               Web      Sports Store
# 11000            Japan               Web  Department Store
# 12000            China         Telephone     Outdoors Shop
# 13000      Netherlands               Web     Outdoors Shop
# 14000           France         Telephone         Golf Shop
# ...

# %%
writer = pd.ExcelWriter('export_data/salesNewSlice1000.xlsx')
df_pt.to_excel(writer,'SalesSheet',encoding = 'utf8',index_label = 'id')
writer.save()

# %%
df_pt[['Year','Status','Gross margin']]
#sqr bracket 2 ชั้น ถ้าจะดูหลายๆคอลัมน์
# Out:
#        Year  Status  Gross margin
# 0      2012  Silver     34.754797
# 1000   2012  Bronze     24.468085
# 2000   2012  Silver     49.540816
# 3000   2012  Silver     49.020619
# 4000   2012  Silver     39.814629
# 5000   2012  Bronze     29.165733
# 6000   2012  Silver     46.582278
# 7000   2012    Gold     54.000000
# 8000   2012  Bronze     28.415201
# 9000   2012  Silver     35.209740
# 10000  2012    Gold     53.750000
# 11000  2012    Gold     51.729686
# 12000  2012  Bronze     28.415201
# 13000  2012  Silver     32.688226
# 14000  2012  Silver     35.798319
# 15000  2012    Gold     51.729686
# 16000  2012  Silver     37.984669
# 17000  2012  Silver     47.876923
# 18000  2012  Silver     40.127226
# 19000  2012  Silver     44.022346
# 20000  2012  Silver     39.814629
# 21000  2012  Silver     32.465170
# 22000  2012  Silver     37.608319
# 23000  2012  Silver     40.241439
# 24000  2012  Bronze     28.293788
# 25000  2012  Bronze     24.341580
# ...

# %%
#sort ascending=[1] เรียงน้อยไปมาก, ascending=[0] เรียงมากไปน้อย
df_pt.sort_values(by=['Gross margin'],ascending=[0])
# Out:
#       Retailer country Order method type     Retailer type  \
# 38000      Netherlands               Web  Direct Marketing
# 62000            Korea               Web  Department Store
# 33000          Belgium               Web      Sports Store
# 79000        Australia               Web   Warehouse Store
# 47000          Denmark               Web  Direct Marketing
# 50000          Austria               Web      Sports Store
# 52000           Canada               Web      Sports Store
# 69000           Brazil               Web      Sports Store
# 82000   United Kingdom               Web     Outdoors Shop
# 54000            China               Web   Warehouse Store
# 39000          Finland               Web     Eyewear Store
# 60000           Canada            E-mail     Outdoors Shop
# 45000        Singapore               Web  Department Store
# 41000   United Kingdom               Web      Sports Store
# 70000            Korea               Web  Department Store
# ...

# %%
df_pt.sort_values(by=['Retailer country'],ascending=[1])
# Out:
#       Retailer country Order method type     Retailer type  \
# 79000        Australia               Web   Warehouse Store
# 4000         Australia       Sales visit   Warehouse Store
# 46000        Australia               Web  Department Store
# 50000          Austria               Web      Sports Store
# 25000          Austria         Telephone     Outdoors Shop
# 58000          Belgium               Web     Eyewear Store
# 66000          Belgium               Web      Sports Store
# 33000          Belgium               Web      Sports Store
# 2000            Brazil               Web     Outdoors Shop
# 36000           Brazil               Web      Sports Store
# 61000           Brazil               Web      Sports Store
# 69000           Brazil               Web      Sports Store
# 68000           Canada               Web  Department Store
# 1000            Canada            E-mail     Outdoors Shop
# 52000           Canada               Web      Sports Store
# ...

# %%
#sort order by 2 columns
df_pt.sort_values(by=['Retailer country','Year'],ascending=[1,1])
# Out:
#       Retailer country Order method type     Retailer type  \
# 4000         Australia       Sales visit   Warehouse Store
# 46000        Australia               Web  Department Store
# 79000        Australia               Web   Warehouse Store
# 25000          Austria         Telephone     Outdoors Shop
# 50000          Austria               Web      Sports Store
# 33000          Belgium               Web      Sports Store
# 58000          Belgium               Web     Eyewear Store
# 66000          Belgium               Web      Sports Store
# 2000            Brazil               Web     Outdoors Shop
# 36000           Brazil               Web      Sports Store
# 61000           Brazil               Web      Sports Store
# 69000           Brazil               Web      Sports Store
# 1000            Canada            E-mail     Outdoors Shop
# 10000           Canada               Web      Sports Store
# 27000           Canada               Web  Department Store
# ...

# %%
df_pt.sort_values(by=['Year','Quarter','Revenue'],ascending=[1,1,0])
# Out:
#       Retailer country Order method type     Retailer type  \
# 0        United States               Fax     Outdoors Shop
# 4000         Australia       Sales visit   Warehouse Store
# 5000           Finland               Web     Outdoors Shop
# 8000             Italy            E-mail      Sports Store
# 1000            Canada            E-mail     Outdoors Shop
# 6000           Germany               Web     Outdoors Shop
# 2000            Brazil               Web     Outdoors Shop
# 3000         Singapore               Web     Outdoors Shop
# 7000    United Kingdom               Web  Department Store
# 13000      Netherlands               Web     Outdoors Shop
# 16000   United Kingdom       Sales visit   Warehouse Store
# 12000            China         Telephone     Outdoors Shop
# 9000     United States               Web         Golf Shop
# 15000          Germany               Web      Sports Store
# 10000           Canada               Web      Sports Store
# ...

# %%
# filter
df_pt[df['Year'] == 2012]
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
#       Retailer country Order method type     Retailer type  \
# 0        United States               Fax     Outdoors Shop
# 1000            Canada            E-mail     Outdoors Shop
# 2000            Brazil               Web     Outdoors Shop
# 3000         Singapore               Web     Outdoors Shop
# 4000         Australia       Sales visit   Warehouse Store
# 5000           Finland               Web     Outdoors Shop
# 6000           Germany               Web     Outdoors Shop
# 7000    United Kingdom               Web  Department Store
# 8000             Italy            E-mail      Sports Store
# 9000     United States               Web         Golf Shop
# 10000           Canada               Web      Sports Store
# 11000            Japan               Web  Department Store
# ...

# %%
df_pt[(df['Order method type'] == 'E-mail') & (df['Year'] == 2013)]
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#       Retailer country Order method type  Retailer type          Product line  \
# 60000           Canada            E-mail  Outdoors Shop  Personal Accessories
#
#       Product type    Product  Year Quarter   Revenue  Quantity  Gross margin  \
# 60000      Eyewear  Polar Sun  2013      Q4  17696.29       293     56.703072
#
#       Status
# 60000   Gold

# %%
df_pt[(df['Gross margin'] > 30) & (df['Year'] == 2014)]
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#       Retailer country Order method type     Retailer type  \
# 68000           Canada               Web  Department Store
# 69000           Brazil               Web      Sports Store
# 70000            Korea               Web  Department Store
# 71000      Netherlands               Web   Warehouse Store
# 72000          Finland               Web     Eyewear Store
# 73000          Germany               Web     Outdoors Shop
# 74000   United Kingdom       Sales visit  Department Store
# 75000            Italy               Web     Outdoors Shop
# 77000           Mexico               Web      Sports Store
# 79000        Australia               Web   Warehouse Store
# 80000          Denmark               Web      Sports Store
# 81000          Germany               Web  Department Store
# ...

# %%
# filter + sort
df2014 = df_pt[(df['Gross margin'] > 30) & (df['Year'] == 2014)].sort_values(by=['Revenue'],ascending=[0])
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app

# %%
writer = pd.ExcelWriter('export_data/year2014GrossmarginMorethan30.xlsx')
df2014.to_excel(writer,'SalesSheet',encoding = 'utf8',index_label = 'id')
writer.save()

# %%
#group by
df_pt.groupby(df_pt['Product line']).agg(['mean'])
# Out:
#                                  Year      Revenue    Quantity Gross margin
#                                  mean         mean        mean         mean
# Product line
# Camping Equipment         2012.578947  66252.61000  660.789474    36.633828
# Golf Equipment            2012.875000  42862.44125  449.500000    49.446378
# Mountaineering Equipment  2012.250000  38797.95750  503.125000    33.277059
# Outdoor Protection        2012.900000   3360.69500  577.600000    63.541766
# Personal Accessories      2012.923077  46303.82359  834.666667    43.382313

# %%
df_pt.groupby(df_pt['Product line'])['Revenue','Quantity'].agg(['mean'])
#arr() > mean,min,max,sum,std,....
# Out:
#                               Revenue    Quantity
#                                  mean        mean
# Product line
# Camping Equipment         66252.61000  660.789474
# Golf Equipment            42862.44125  449.500000
# Mountaineering Equipment  38797.95750  503.125000
# Outdoor Protection         3360.69500  577.600000
# Personal Accessories      46303.82359  834.666667

# %%
df_pt.groupby(df_pt['Product line'])['Revenue'].agg(['mean']).to_csv('export_data/mean.csv')

# %%
df_pt.groupby(df_pt['Product line'])['Revenue','Quantity'].agg(['sum'])
# Out:
#                              Revenue Quantity
#                                  sum      sum
# Product line
# Camping Equipment         1258799.59    12555
# Golf Equipment             342899.53     3596
# Mountaineering Equipment   310383.66     4025
# Outdoor Protection          33606.95     5776
# Personal Accessories      1805849.12    32552

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
df_pt.groupby(df_pt['Product line'])['Revenue'].agg(['sum']).plot()

# %%
df_pt.groupby(df_pt['Product line'])['Revenue'].agg(['sum']).sort_values(by=['sum'])

# %%
# Filter by year -> group by product line and filter revenue to sum -> order by sum
df_pt[df_pt['Year'] == 2012].groupby(['Product line'])['Revenue'].agg(['sum']).sort_values(by=['sum'])
# Out:
#                                 sum
# Product line
# Outdoor Protection         11217.85
# Mountaineering Equipment  139995.12
# Golf Equipment            221359.25
# Camping Equipment         394621.55
# Personal Accessories      668098.75

# %%
df_pt.groupby(['Retailer country'])['Revenue'].agg(['sum'])
# Out:
#                         sum
# Retailer country
# Australia          64969.07
# Austria            21739.82
# Belgium           180818.57
# Brazil            222332.90
# Canada            386674.69
# China             316939.60
# Denmark             6848.40
# Finland            74780.72
# France            229279.08
# Germany           135852.46
# Italy             378447.68
# Japan              99527.34
# Korea              61313.02
# Mexico             76001.85
# Netherlands       380101.57
# Singapore         184881.12
# Spain             148515.89
# Sweden              4125.55
# Switzerland        90296.99
# United Kingdom    137184.85
# United States     550907.68

# %%
df_pt.groupby(['Retailer country'])['Revenue'].agg(['sum','mean','min']).sort_values(by=['mean','sum'],ascending=[0,0])
# Out:
#                         sum          mean       min
# Retailer country
# China             316939.60  79234.900000  12584.70
# United States     550907.68  78701.097143  29036.00
# Italy             378447.68  75689.536000   3640.00
# Netherlands       380101.57  63350.261667   1225.00
# Belgium           180818.57  60272.856667  10395.85
# Brazil            222332.90  55583.225000  15366.40
# Canada            386674.69  55239.241429   2925.00
# Spain             148515.89  49505.296667  13307.30
# Singapore         184881.12  46220.280000  10456.60
# France            229279.08  45855.816000   1190.00
# Japan              99527.34  33175.780000   8166.51
# Mexico             76001.85  25333.950000   5325.25
# Finland            74780.72  24926.906667   9198.00
# United Kingdom    137184.85  22864.141667    143.50
# Germany           135852.46  22642.076667    570.00
# Switzerland        90296.99  22574.247500    414.00
# Australia          64969.07  21656.356667   1565.10
# ...

# %%
df_pt.groupby(['Retailer country'])['Revenue','Gross margin'].agg(['sum','mean','min']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, Australia to United States
# Data columns (total 6 columns):
# (Revenue, sum)          21 non-null float64
# (Revenue, mean)         21 non-null float64
# (Revenue, min)          21 non-null float64
# (Gross margin, sum)     21 non-null float64
# (Gross margin, mean)    21 non-null float64
# (Gross margin, min)     21 non-null float64
# dtypes: float64(6)
# memory usage: 1.1+ KB

# %%
df_big = df_pt.groupby(['Retailer country'])['Revenue','Gross margin'].agg(['sum','mean','min']).sort_values(by=[('Gross margin','mean')],ascending=[0]).T

# %%
df_big.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6 entries, (Revenue, sum) to (Gross margin, min)
# Data columns (total 21 columns):
# Denmark           6 non-null float64
# Korea             6 non-null float64
# Australia         6 non-null float64
# Belgium           6 non-null float64
# United Kingdom    6 non-null float64
# Brazil            6 non-null float64
# Canada            6 non-null float64
# Germany           6 non-null float64
# Japan             6 non-null float64
# Mexico            6 non-null float64
# Austria           6 non-null float64
# Netherlands       6 non-null float64
# France            6 non-null float64
# Finland           6 non-null float64
# Singapore         6 non-null float64
# Spain             6 non-null float64
# Switzerland       6 non-null float64
# Sweden            6 non-null float64
# Italy             6 non-null float64
# China             6 non-null float64
# United States     6 non-null float64
# dtypes: float64(21)
# ...

# %%
plt.plot(df_big[('Revenue','sum')],df_big['Data columns'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Revenue', 'sum')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-c0391c6f36f7> in <module>()
# ...
