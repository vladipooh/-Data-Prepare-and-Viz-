# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import IFrame, YouTubeVideo
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('import_data/carData.csv')

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f750385bcc0>,
# ...
#       dtype=object)

# %%
df['cty'].hist();

# %%
df['cty'].hist(bins=20);

# %%
df['cty'].hist(bins=20,grid=False);

# %%
df['cty'].hist(bins=50,grid=False,color='pink');

# %%
df[['cty','hwy']].hist(bins=10,grid=False,color='pink');

# %%
df[['cty','hwy']].hist(bins=10,grid=False,color='pink',sharex=1,sharey=1);

# %%
df[['cty','hwy']].plot.hist();

# %%
df[['cty','hwy']].plot.hist(alpha=.8);

# %%
df[['cty','hwy']].plot.density();
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df[['cty','hwy']].plot.kde();

# %%
df['trans'].hist()
